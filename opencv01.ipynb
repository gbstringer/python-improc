# %% [markdown]
# # Image processing with OpenCV
#
# ### Import numpy, scikit-image and open computer vision libraries
# * **numpy** provides the matrix arithmetic (not currently used)
# * **cv2** provides the image processing functions
# * **skimage** provides the embedded image display in Jupyter
# * **matplotlib** is used to lay out side-by-side comparisons (not currently used)

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2 as cv
from skimage import io

# %% [markdown]
# ### Helper functions
#
# * **makethumb()** is a quick rescaling function, reducing an image to 10% linear size
# * **showbriefly()** shows an image for 10 seconds or until a key is pressed

# %%
def makethumb(i):
    return cv.resize(i,None,fx=0.1,fy=0.1,interpolation=cv.INTER_LINEAR)

def showbriefly(i):
    v = cv.imshow('Image',i)
    cv.waitKey(10000)
    cv.destroyWindow(v)

# %% [markdown]
# ### Load the image
# * Image is read as a BGR matrix

# %%
img = cv.imread(filename='data/uoedh_culver house letters12659.jpg')

# %%
io.imshow(makethumb(img))
showbriefly(img)

# %% [markdown]
# #### Convert to grayscale

# %%
grey = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

io.imshow(makethumb(grey))
#showbriefly(grey)

# %% [markdown]
# ### Use cv.threshold() to isolate writing
# * note that **cv.threshold() returns two arguments:
#  * **ret** the threshold mask pattern (temporary variable)
#  * **thresh** the image with threshold applied

# %%
ret,thresh = cv.threshold(grey,127,255,cv.THRESH_BINARY_INV)

io.imshow(makethumb(thresh))
#showbriefly(thresh)

# %% [markdown]
# ### Apply further threshold

# %%
new = img

cv.subtract(img,thresh,new,mask=0,dtype=-1)

#ret,through = cv.threshold(thresh,170, 180,cv.THRESH_BINARY)

io.imshow(makethumb(new))
showbriefly(new)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-e5dded3efd6f> in <module>
#       1 new = img
#       2
# ----> 3 cv.subtract(img,thresh,new,mask=0,dtype=-1)
#       4
#       5 #ret,through = cv.threshold(thresh,170, 180,cv.THRESH_BINARY)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\core\src\arithm.cpp:669: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %% [markdown]
# #### Remove image windows

# %%
cv.destroyAllWindows()
