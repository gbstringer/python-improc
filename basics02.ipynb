# %%
import sys
import numpy as np
#import skimage.io
import matplotlib.pyplot as plt
#import skimage.viewer
from skimage import io, color, viewer, data

# %% [markdown]
# Load the image into an array

# %%
image = skimage.io.imread(fname='data/uoedh_culver house letters12659.jpg')
viewer1 = skimage.io.imshow(image)

# %% [markdown]
# Crop the image to the outer border

# %%
clip = image[100:1600, 200:1700, :]
viewer2 = skimage.io.imshow(clip)

# %% [markdown]
# Greyscale the image

# %%
grey = skimage.color.rgb2gray(clip)
viewer3 = skimage.io.imshow(grey)

# %% [markdown]
# Use threshold to blank out print-through
